# %%
print("Hello form Git Folder!")

# %%
# %sh
git config --global user.email "192157305+Geeta-Ladde@users.noreply.github.com"
# Since your last commit was already rejected, we need to "fix" the last commit's author:
git commit --amend --reset-author --no-edit
